# %% [markdown]
# <a href="https://colab.research.google.com/github/codingprahlad/Python-learning/blob/main/Integers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(12 + 8)
# Out:
# 20

# %%
print(20 - 5)
# Out:
# 15

# %%
print(6 * 7)
# Out:
# 42

# %%
a = 10
b = 3
print(a + b)
# Out:
# 13

# %%
x = 15
y = 4
print(x - y)
# Out:
# 11

# %%
m = 6
n = 7
print(m * n)
# Out:
# 42

# %%
a = 10
b = 15
c = 9
print ( a < b )
print ( a > c )
print ( b < b )
print(type(a))
# Out:
# True
# True
# False
# <class 'int'>

# %%
p = 20
q = 5
print(p / q)
# Out:
# 4.0

# %%
r = 17
s = 3
print(r // s)
# Out:
# 5

# %%
ramesh = 2000
suresh = 2000
print(suresh == ramesh)
print(type(ramesh))
# Out:
# True
# <class 'int'>

# %%
u = 18
v = 5
print(u % v)
# Out:
# 3

# %%
i = 9
print(i ** 2)
# Out:
# 81

# %%
a = 10
b = 2.5
print(a + b)
# Out:
# 12.5

# %%
p = 9
q = 2
print(float(p / q))
# Out:
# 4.5

# %%
a = 5
b = 3j
print(a + b)
# Out:
# (5+3j)

# %%
x = 4 + 2j
y = 1
print(x * y)
# Out:
# (4+2j)

# %%
c1 = 2 + 3j
c2 = 1 + 4j
print(c1 + c2)
# Out:
# (3+7j)

# %%
z = 6 + 8j
print(abs(z))
# Out:
# 10.0

# %%
num = 12
print(type(num))
a = 10
b = 3
print(a + b)
# Out:
# <class 'int'>
# 13

# %%
x = 15
y = 4
print(x - y)
# Out:
# 11

# %%
m = 6
n = 7
print(m * n)
# Out:
# 42

# %%
p = 20
q = 5
print(p / q)
# Out:
# 4.0

# %%
r = 17
s = 3
print(r // s)
# Out:
# 5

# %%
u = 18
v = 5
print(u % v)
# Out:
# 3

# %%
i = 9
print(i ** 2)
# Out:
# 81

# %%
a = 10
b = 2.5
print(a + b)
# Out:
# 12.5

# %%
x = 7
y = 2.0
print(x * y)
# Out:
# 14.0

# %%
p = 9
q = 2
print(float(p / q))
# Out:
# 4.5

# %%
a = 5
b = 3j
print(a + b)
# Out:
# (5+3j)

# %%
x = 4 + 2j
y = 1
print(x * y)
# Out:
# (4+2j)

# %%
c1 = 2 + 3j
c2 = 1 + 4j
print(c1 + c2)
# Out:
# (3+7j)

# %%
z = 6 + 8j
print(abs(z))
# Out:
# 10.0

# %%
num = 12
print(type(num))
# Out:
# <class 'int'>

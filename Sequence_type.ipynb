# %% [markdown]
# <a href="https://colab.research.google.com/github/codingprahlad/Python-learning/blob/main/Sequence_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "python"
print(len(name))
# Out:
# 6

# %%
text = "data"
print(text[0])
# Out:
# d

# %%
word = "analytics"
print(word[-1])
# Out:
# s

# %%
s = "hello"
print(s.upper())
# Out:
# HELLO

# %%
msg = "WELCOME"
print(msg.lower())
# Out:
# welcome

# %%
a = "data"
b = "science"
print(a + b)
# Out:
# datascience

# %%
lang = "python"
print(lang[1:4])
# Out:
# yth

# %%
items = ["apple", "banana", "mango"]
print(len(items))
# Out:
# 3

# %%
nums = [1, 2, 3]
nums.append(4)
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
values = [10, 20, 30]
print(values[0])
# Out:
# 10

# %%
marks = [45, 67, 89, 90]
print(max(marks))
# Out:
# 90

# %%
scores = [100, 50, 75]
scores.remove(50)
print(scores)
# Out:
# [100, 75]

# %%
data = [1, 2, 3, 4]
print(data[::-1])
# Out:
# [4, 3, 2, 1]

# %%
lst = ["a", "b", "c"]
lst[1] = "z"
print(lst)
# Out:
# ['a', 'z', 'c']

# %%
name = "prahlad data analyst"
print(name.lower())
# Out:
# prahlad data analyst

# %%
colors = ["red", "blue"]
colors.insert(1, "green")
print(colors)
# Out:
# ['red', 'green', 'blue']

# %%
tup = (10, 20, 30)
print(tup[2])
# Out:
# 30

# %%
letters = ("a", "b", "c")
print(letters.index("b"))
# Out:
# 1

# %%
lst = ["p", "y", "t"]
print(tuple(lst))
# Out:
# ('p', 'y', 't')

# %%
text = "python"
print(list(text))
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
letters = ("a", "b", "c")
print(letters.index("b"))
# Out:
# 1

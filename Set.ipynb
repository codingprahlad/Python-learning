# %% [markdown]
# <a href="https://colab.research.google.com/github/codingprahlad/Python-learning/blob/main/Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {1, 2, 3}
print(a)
# Out:
# {1, 2, 3}

# %%
nums = {1, 2, 2, 3}
print(nums)
# Out:
# {1, 2, 3}

# %%
s = set([4, 5, 6])
print(s)
# Out:
# {4, 5, 6}

# %%
s = set([4, 5, 6])
print(s)
# Out:
# {4, 5, 6}

# %%
data = {10, 20, 30}
print(len(data))
# Out:
# 3

# %%
items = {"apple", "banana"}
items.add("mango")
print(items)
# Out:
# {'apple', 'banana', 'mango'}

# %%
nums = {10, 20, 30}
print(20 in nums)
# Out:
# True

# %%
q = {2, 3, 4}
print(p.symmetric_difference(q))
# Out:
# {1, 4}

# %%
x = {1, 2, 3}
y = {2, 3, 4}
print(x.intersection(y))
# Out:
# {2, 3}

# %%
nums = {5, 10, 15}
nums.discard(20)
print(nums)
# Out:
# {10, 5, 15}

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
values = {1, 2, 3}
values.remove(2)
print(values)
# Out:
# {1, 3}

# %%
m = {1, 2, 3}
n = {2, 3, 4}
print(m.difference(n))
# Out:
# {1}

# %%
p = {1, 2, 3}
q = {2, 3, 4}
print(p.symmetric_difference(q))
# Out:
# {1, 4}

# %%
nums = {10, 20, 30}
print(20 in nums)
# Out:
# True

# %%
letters = {"a", "b", "c"}
print("d" not in letters)
# Out:
# True

# %%
a = {1, 2}
b = {1, 2, 3}
print(a.issubset(b))
# Out:
# True

# %%
data = {10, 20, 30, 40}
data.add(50)
data.remove(20)
data.discard(100)
print(len(data))
print(30 in data)
# Out:
# 4
# True

# %%
x = {1, 2, 3}
y = {1, 2}
print(x.issuperset(y))
# Out:
# True

# %%
s = {1, 2, 3}
s.pop()
print(s)
# Out:
# {2, 3}

# %%
data = {5, 6, 7}
data.clear()
print(data)
# Out:
# set()

# %%
unique = set("python")
print(unique)
# Out:
# {'n', 'o', 'p', 'y', 't', 'h'}

# %% [markdown]
# <a href="https://colab.research.google.com/github/codingprahlad/Python-learning/blob/main/Conditionall_Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 20

if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %%
vote = 18

if( vote <= 17 ) :
  print("not elligible")
else:
  print("he can vote")
# Out:
# he can vote

# %%
n =int(input("Enter a number:"))

if ( n % 2 == 0):
  print("even number")
else:
  print("odd number")
# Out:
# Enter a number:56
# even number

# %%
pos = int(input("Enter a number:"))
if ( pos > 0 ) :
  print("positive number")
else :
  print("negetive  number")
# Out:
# Enter a number:-9
# negetive  number

# %%
student = 21


if ( student >= 25) :
  print("pass")
else:
  print("fail")
# Out:
# fail

# %%
num = 56

if( num % 3 == 0):
  print("divisible")
else:
  print("not divisible")
# Out:
# not divisible

# %%
a = 15
b = 20

if (a == b) :
  print("equal numbers")
else:
  print("not equal numbers")
# Out:
# not equal numbers

# %%
username = str(input("Enter your username:"))
password = int(input("Enter your password:"))

if (username == "prahlad" and password == 1234) :
  print("Login succesfully")
else :
  print("Unseccesfull")
# Out:
# Enter your username:prahlad
# Enter your password:7853
# Unseccesfull

# %%
fruits = ["apple", "banana", "mango"]

if "banana" in fruits:
    print("Banana is available")
# Out:
# Banana is available

# %%
age = int(input("Enter your age:"))


if (age <= 12):
  print("Child")
elif (age <= 18) :
  print("Teenager")
elif (age <= 30) :
  print("Young adult")
else :
  print("Very young")
# Out:
# Enter your age:21
# Young adult

# %%
a = 25

if (a != 0):
  if(a > 0):
    if (a % 2 == 0):
